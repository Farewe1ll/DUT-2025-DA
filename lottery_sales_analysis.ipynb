# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from datetime import datetime, timedelta
import warnings
from statsmodels.tsa.stattools import adfuller
import statsmodels.graphics.tsaplots as tsaplots
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.dates as mdates

# %%
# 导入 csv
file_path = './sample_lottery_data.csv'
data = pd.read_csv(file_path)

# 处理 date 并且排序
data['date'] = pd.to_datetime(data['date'])
data = data.sort_values('date')
data.reset_index(drop=True, inplace=True)  # 确保索引正确

# 查看日期范围信息
print(f"数据日期范围: {data['date'].min()} 到 {data['date'].max()}")
print(f"总天数: {(data['date'].max() - data['date'].min()).days + 1}天")

# sans-serif 字体设置
plt.rcParams['font.sans-serif'] = ['Source Han Sans SC']
plt.rcParams['axes.unicode_minus'] = False
# Out:
# 数据日期范围: 2024-10-30 00:00:00 到 2025-06-30 00:00:00
# 总天数: 244天

# %%
plt.figure(figsize=(12, 6))
plt.plot(data['date'], data['total_sales'], 'o-', markersize=4, label='总销售额')

x = np.arange(len(data))
z = np.polyfit(x, data['total_sales'], 1)
p = np.poly1d(z)
plt.plot(data['date'], p(x), 'r--', label='趋势线')

plt.title('大乐透总销售额随开奖日期的变化趋势')
plt.xlabel('日期')
plt.ylabel('总销售额（元）')
plt.grid(True, linestyle='--', alpha=0.7)
plt.gcf().autofmt_xdate()
plt.xticks(rotation=45)
plt.tight_layout()
# plt.savefig('./sales_trend.png')
plt.show()
plt.close()

# %%
last_date = data['date'].max()
next_date = last_date + timedelta(2)

ts_data = data.set_index('date')['total_sales']
ts_data -= 2.8e8

ts_data = pd.Series(ts_data.values, index=pd.DatetimeIndex(ts_data.index))

# 定义函数检查序列是否平稳
def adf_test(seq):
    res = adfuller(seq, autolag='AIC')
    return res[1] < 0.05

# 确定非季节性部分最优差分阶数d
def findd(seq, maxd = 5):
    d = 0
    nseq = seq.copy()

    res = adf_test(nseq)

    while not res and d < maxd:
        d += 1
        nseq = nseq.diff().dropna()
        res = adf_test(nseq)

    return d

d = findd(ts_data)
print(f"选择的最优非季节性部分差分阶数d: {d}")

# 确定季节性部分最优差分阶数d
def findD(seq, s = 7, maxD=5):
    D = 0
    nseq = seq.copy()

    acf_values = pd.Series(tsaplots.acf(nseq, nlags=s*3))

    seasonal_corr = np.mean([abs(acf_values[s]), abs(acf_values[2*s])])

    while seasonal_corr > 0.2 and D < maxD:
        D += 1
        nseq = nseq.diff(s).dropna()

        if len(nseq) > s*3:
            acf_values = pd.Series(tsaplots.acf(nseq, nlags=s*3))
            seasonal_corr = np.mean([abs(acf_values[s]), abs(acf_values[2*s])])

    return D

D = findD(ts_data)
print(f"选择的最优季节性差分阶数D: {D}")

# 使用AIC网格搜索法确定p、q、P、Q的最佳参数
def sarima_grid_search(ts_data, d, D, s=7, maxp=5, maxq=5, maxP=5, maxQ=5):
    best_aic = float('inf')
    best_params = None

    warnings.filterwarnings("ignore")  # 抑制警告信息

    for p in range(maxp + 1):
        for q in range(maxq + 1):
            for P in range(maxP + 1):
                for Q in range(maxQ + 1):
                    # 跳过p=q=P=Q=0的情况
                    if p == 0 and q == 0 and P == 0 and Q == 0:
                        continue

                    try:
                        model = SARIMAX(ts_data,
                                        order=(p, d, q),
                                        seasonal_order=(P, D, Q, s),
                                        enforce_stationarity=False,
                                        enforce_invertibility=False)

                        model_fit = model.fit(disp=False)
                        aic = model_fit.aic

                        print(f"SARIMA({p},{d},{q})x({P},{D},{Q},{s}) - AIC: {aic}")

                        if aic < best_aic:
                            best_aic = aic
                            best_params = (p, d, q, P, D, Q, s)

                    except:
                        continue

    print(f"\n最佳参数: SARIMA{best_params[:3]}x{best_params[3:]} - AIC: {best_aic}")
    return best_params

# 执行网格搜索
print("执行SARIMA参数网格搜索，这可能需要一些时间...")
best_params = sarima_grid_search(ts_data, d, D)

# 使用最佳参数构建模型
p, d, q, P, D, Q, s = best_params

# order=(p,d,q)为非季节性参数，seasonal_order=(P,D,Q,s)为季节性参数
model = SARIMAX(ts_data,
                order=(p, d, q),    # 非季节性部分 (p,d,q)
                seasonal_order=(P, D, Q, s) # 季节性部分 (P,D,Q,s)
               )

# 拟合模型
model_fit = model.fit(disp=False)  # 抑制收敛信息输出

forecast = model_fit.forecast(steps=1)

predicted_sales = forecast.iloc[0] + 2.8e8
ts_data += 2.8e8

print(f"预测{next_date.strftime('%Y-%m-%d')}的大乐透总销售额为：{predicted_sales:.2f}元")
# Out:
# 选择的最优非季节性部分差分阶数d: 1
# 选择的最优季节性差分阶数D: 1
# 执行SARIMA参数网格搜索，这可能需要一些时间...
# SARIMA(0,1,0)x(0,1,1,7) - AIC: 3108.656613334871
# SARIMA(0,1,0)x(0,1,2,7) - AIC: 2850.4714773183136
# SARIMA(0,1,0)x(0,1,3,7) - AIC: 2591.5562073449796
# SARIMA(0,1,0)x(0,1,4,7) - AIC: 6345.261856400818
# SARIMA(0,1,0)x(0,1,5,7) - AIC: 2078.7124263201795
# SARIMA(0,1,0)x(1,1,0,7) - AIC: 3183.460503627306
# SARIMA(0,1,0)x(1,1,1,7) - AIC: 3105.2985833772454
# SARIMA(0,1,0)x(1,1,2,7) - AIC: 2840.949543379112
# SARIMA(0,1,0)x(1,1,3,7) - AIC: 2587.999192804978
# SARIMA(0,1,0)x(1,1,4,7) - AIC: 6249.95416092666
# SARIMA(0,1,0)x(1,1,5,7) - AIC: 2080.146138079777
# SARIMA(0,1,0)x(2,1,0,7) - AIC: 2871.4070538085557
# SARIMA(0,1,0)x(2,1,1,7) - AIC: 2858.755918395271
# SARIMA(0,1,0)x(2,1,2,7) - AIC: 2819.6126399029486
# SARIMA(0,1,0)x(2,1,3,7) - AIC: 2552.399005345171
# SARIMA(0,1,0)x(2,1,4,7) - AIC: 6156.581649414654
# SARIMA(0,1,0)x(2,1,5,7) - AIC: 2074.69835655695
# SARIMA(0,1,0)x(3,1,0,7) - AIC: 2612.602149510862
# SARIMA(0,1,0)x(3,1,1,7) - AIC: 2612.868617659947
# SARIMA(0,1,0)x(3,1,2,7) - AIC: 2613.807799762681
# SARIMA(0,1,0)x(3,1,3,7) - AIC: 2551.7052593525304
# SARIMA(0,1,0)x(3,1,4,7) - AIC: 5279.022699859641
# SARIMA(0,1,0)x(3,1,5,7) - AIC: 2076.7757507215874
# SARIMA(0,1,0)x(4,1,0,7) - AIC: 2361.791898747723
# SARIMA(0,1,0)x(4,1,1,7) - AIC: 2362.5980322004775
# SARIMA(0,1,0)x(4,1,2,7) - AIC: 2350.673254841822
# SARIMA(0,1,0)x(4,1,3,7) - AIC: 2334.6472345882894
# SARIMA(0,1,0)x(4,1,4,7) - AIC: 3410.51939179288
# SARIMA(0,1,0)x(4,1,5,7) - AIC: 2078.341130025576
# SARIMA(0,1,0)x(5,1,0,7) - AIC: 2090.2238578315837
# SARIMA(0,1,0)x(5,1,1,7) - AIC: 2079.4723364458664
# SARIMA(0,1,0)x(5,1,2,7) - AIC: 2085.9320220645445
# SARIMA(0,1,0)x(5,1,3,7) - AIC: 2061.442311386063
# SARIMA(0,1,0)x(5,1,4,7) - AIC: 5435.650757964211
# SARIMA(0,1,1)x(0,1,0,7) - AIC: 3372.8154968860845
# SARIMA(0,1,1)x(0,1,1,7) - AIC: 3072.3355540397242
# SARIMA(0,1,1)x(0,1,2,7) - AIC: 2815.526854389385
# SARIMA(0,1,1)x(0,1,3,7) - AIC: 2559.6197471947767
# SARIMA(0,1,1)x(0,1,4,7) - AIC: 6397.8946087808545
# SARIMA(0,1,1)x(0,1,5,7) - AIC: 2041.5543927137662
# SARIMA(0,1,1)x(1,1,0,7) - AIC: 3170.4798019535456
# SARIMA(0,1,1)x(1,1,1,7) - AIC: 3073.2880074501686
# SARIMA(0,1,1)x(1,1,2,7) - AIC: 2817.8108173907326
# SARIMA(0,1,1)x(1,1,3,7) - AIC: 2561.2752908341226
# SARIMA(0,1,1)x(1,1,4,7) - AIC: 6411.643775384012
# SARIMA(0,1,1)x(1,1,5,7) - AIC: 2043.5048475243698
# SARIMA(0,1,1)x(2,1,0,7) - AIC: 2895.0660551551036
# SARIMA(0,1,1)x(2,1,1,7) - AIC: 2888.9577375663216
# SARIMA(0,1,1)x(2,1,2,7) - AIC: 2817.202575682219
# SARIMA(0,1,1)x(2,1,3,7) - AIC: 2557.3297618250485
# SARIMA(0,1,1)x(2,1,4,7) - AIC: 6126.144181781063
# SARIMA(0,1,1)x(2,1,5,7) - AIC: 2040.6488398660595
# SARIMA(0,1,1)x(3,1,0,7) - AIC: 2636.1212331429174
# SARIMA(0,1,1)x(3,1,1,7) - AIC: 2637.501245115412
# SARIMA(0,1,1)x(3,1,2,7) - AIC: 2635.657679613826
# SARIMA(0,1,1)x(3,1,3,7) - AIC: 2559.0420572870917
# SARIMA(0,1,1)x(3,1,4,7) - AIC: 5283.325002982977
# SARIMA(0,1,1)x(3,1,5,7) - AIC: 2042.7030710757506
# SARIMA(0,1,1)x(4,1,0,7) - AIC: 2380.9058573002662
# SARIMA(0,1,1)x(4,1,1,7) - AIC: 2382.3996622610584
# SARIMA(0,1,1)x(4,1,2,7) - AIC: 2378.8261003018906

# %%
# 获取拟合值
fitted_values = model_fit.fittedvalues + 2.8e8

# 根据特定开奖规律创建预测日期
last_date = ts_data.index[-1]  # 最后一个已知开奖日期

# 计算未来三次开奖日期
forecast_dates = [
    last_date + pd.Timedelta(days=2),  # 上次开奖后2天
    last_date + pd.Timedelta(days=5),  # 上次开奖后5天
    last_date + pd.Timedelta(days=7)   # 上次开奖后7天
]

# 创建预测，设置步数为7天（覆盖最远的预测日期）
forecast_steps = 7  # 预测足够多的天数来覆盖所有开奖日
forecast = model_fit.get_forecast(steps=forecast_steps)
forecast_mean = forecast.predicted_mean
forecast_ci = forecast.conf_int(alpha=0.05)

# 创建连续的预测日期序列（用于获取预测值）
continuous_forecast_index = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=forecast_steps, freq='D')

# 筛选只需要的开奖日预测结果
forecast_values = []
forecast_lower = []
forecast_upper = []
for date in forecast_dates:
    # 找出预测序列中对应的索引位置
    days_ahead = (date - last_date).days - 1  # 减1是因为forecast从last_date后一天开始
    if 0 <= days_ahead < len(forecast_mean):
        forecast_values.append(forecast_mean.iloc[days_ahead] + 2.8e8)
        forecast_lower.append(forecast_ci.iloc[days_ahead, 0] + 2.8e8)
        forecast_upper.append(forecast_ci.iloc[days_ahead, 1] + 2.8e8)

# 创建预测图
plt.figure(figsize=(14, 7))

# 绘制实际值
plt.plot(ts_data.index, ts_data.values, 'b-', label='实际销售额')

# 绘制拟合值
plt.plot(fitted_values.index, fitted_values.values, 'r--', label='模型拟合值')

# 绘制预测值（只针对开奖日）
plt.plot(forecast_dates, forecast_values, 'g-o', markersize=6, label='预测开奖日销售额')

# 添加预测的置信区间
for i in range(len(forecast_dates)):
    plt.fill_between([forecast_dates[i]], [forecast_lower[i]], [forecast_upper[i]],
                     color='g', alpha=0.2)

# 添加图例和标签
plt.title(f'大乐透总销售额: 实际值 vs 特定开奖日预测值 (SARIMA{(p,d,q)}x{(P,D,Q,s)})')
plt.xlabel('日期')
plt.ylabel('总销售额（元）')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.gcf().autofmt_xdate()
plt.xticks(rotation=45)

# 使用mdates格式化x轴日期
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=1))

plt.tight_layout()
plt.savefig('./sales_prediction_lottery_days.png')
plt.show()

# 打印具体预测值及置信区间
print(f"预测未来三次开奖的大乐透总销售额:")
for i, (date, mean, lower, upper) in enumerate(zip(forecast_dates, forecast_values, forecast_lower, forecast_upper)):
    print(f"开奖日 {date.strftime('%Y-%m-%d')}: {mean:.2f}元 (95%置信区间: [{lower:.2f}, {upper:.2f}])")
# Out:
# 预测未来三次开奖的大乐透总销售额:
# 开奖日 2025-07-02: 324898795.23元 (95%置信区间: [258786751.64, 391010838.81])
# 开奖日 2025-07-05: 314213116.96元 (95%置信区间: [218245315.73, 410180918.19])
# 开奖日 2025-07-07: 294178950.89元 (95%置信区间: [185518412.04, 402839489.74])
